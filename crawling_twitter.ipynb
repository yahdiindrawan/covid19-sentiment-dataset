# %% [markdown]
# <a href="https://colab.research.google.com/github/yahdiindrawan/covid19-sentiment-dataset/blob/master/crawling_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import csv

# %%
access_token = "XXX"
access_token_secret = "XXX"
consumer_key = "XXX"
consumer_secret = "XXX"

# %%
auth = tweepy.auth.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
api = tweepy.API(auth)

# %%
csvFile = open('Covid-19_sentiment.csv', 'a')

# %%
#Use csv writer
csvWriter = csv.writer(csvFile)

# %%
csvWriter.writerow(['Tanggal','Tweet'])

# %%
for tweet in tweepy.Cursor(api.search,
                           q = "covid",
                           since = "2020-01-01",
                           until = "2020-04-10",
                           lang = "id").items():

    # Write a row to the CSV file. I use encode UTF-8
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
    print(tweet.created_at, tweet.text)
csvFile.close()
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# https://t.co/DhIs9Oijhb #AWANInews #HapusCOVID19 #KekalTenang htt…
# 2020-04-09 18:58:53 RT @kabarsleman: Data Pendatang/Pemudik ke Sleman per 8 April 2020
#
# Menindaklanjuti usulan #Slemanis ttg info data pendatang/pemudik sebaga…
# 2020-04-09 18:58:53 RT @Sijeuniuwu: °• ੈ♡₊˚•.
# 🍑┊❥ "ak kgn, pgn ketemu"
# 💚┊❥ "aku jg, self quarantine:("
# 🍑┊❥ "kalau covid-19 udh selesai ak mau peluk kmu sehari…
# 2020-04-09 18:58:50 RT @mas__piyuuu: dr. Tifauzia Tyassuma: Presiden @Jokowi seharusnya menyampaikan Duka Cita secara personel kepada Para Dokter Pahlawan Covi…
# 2020-04-09 18:58:50 RT @501Awani: Korban termuda COVID-19, wanita 23 tahun lambat ke hospital
# https://t.co/DhIs9Oijhb #AWANInews #HapusCOVID19 #KekalTenang htt…
# 2020-04-09 18:58:49 RT @DrAmalinaBakri: Atas permintaan keluarga Dr Tun Muzamal Wildan, pakar bedah dari Malaysia yang bekerja di UK, saya dengan rendah diri i…
# ...
